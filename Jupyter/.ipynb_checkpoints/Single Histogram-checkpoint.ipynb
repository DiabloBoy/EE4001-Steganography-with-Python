# %%
from PIL import Image 
  
img = Image.open(r"Lena.jpg") 
r, g, b = img.split() 
len(b.histogram()) 

  
#r.histogram() 
g.histogram()
#b.histogram()
# Out:
# [111,
#  20,
#  26,
#  26,
#  35,
#  42,
#  61,
#  65,
#  72,
#  77,
#  100,
#  103,
#  131,
#  131,
#  141,
#  169,
#  195,
#  222,
#  259,
#  295,
#  331,
#  370,
#  387,
#  382,
#  384,
#  379,
#  399,
#  397,
#  366,
#  367,
#  330,
#  299,
#  257,
#  249,
#  194,
#  219,
#  228,
#  199,
#  238,
#  205,
#  191,
#  178,
#  214,
#  194,
#  203,
#  177,
#  188,
#  209,
#  149,
#  225,
#  192,
#  193,
#  195,
#  207,
#  203,
#  217,
#  226,
#  211,
#  241,
#  239,
#  296,
#  273,
#  275,
#  306,
#  448,
#  459,
#  399,
#  392,
#  371,
#  371,
#  371,
#  335,
#  337,
#  288,
#  264,
#  251,
#  242,
#  270,
#  288,
#  285,
#  250,
#  248,
#  236,
#  268,
#  268,
#  315,
#  306,
#  292,
#  311,
#  313,
#  348,
#  404,
#  460,
#  451,
#  449,
#  463,
#  380,
#  397,
#  425,
#  387,
#  359,
#  354,
#  375,
#  417,
#  297,
#  284,
#  296,
#  311,
#  328,
#  282,
#  304,
#  277,
#  312,
#  383,
#  316,
#  333,
#  307,
#  317,
#  312,
#  259,
#  342,
#  310,
#  314,
#  321,
#  339,
#  345,
# ...
